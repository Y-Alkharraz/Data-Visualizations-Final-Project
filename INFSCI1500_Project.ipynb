# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
#Open the first data file
df = pd.read_csv('coffee.csv')

# %%
df.head(5)
# Out:
#          Date    Open    High     Low   Close  Volume Currency
# 0  2000-01-03  122.25  124.00  116.10  116.50    6640      USD
# 1  2000-01-04  116.25  120.50  115.75  116.25    5492      USD
# 2  2000-01-05  115.00  121.00  115.00  118.60    6165      USD
# 3  2000-01-06  119.00  121.40  116.50  116.85    5094      USD
# 4  2000-01-07  117.25  117.75  113.80  114.15    6855      USD

# %%
df.dtypes
# Out:
# Date         object
# Open        float64
# High        float64
# Low         float64
# Close       float64
# Volume        int64
# Currency     object
# dtype: object

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date        datetime64[ns]
# Open               float64
# High               float64
# Low                float64
# Close              float64
# Volume               int64
# Currency            object
# dtype: object

# %%
df['Open'].mean()
# Out:
# 127.2676348764365

# %%
df['year'] = df['Date'].dt.year
df['day'] = df['Date'].dt.dayofyear
df['month'] =df['Date'].dt.month
df
# Out:
#            Date    Open    High     Low   Close  Volume Currency  year  day  \
# 0    2000-01-03  122.25  124.00  116.10  116.50    6640      USD  2000    3
# 1    2000-01-04  116.25  120.50  115.75  116.25    5492      USD  2000    4
# 2    2000-01-05  115.00  121.00  115.00  118.60    6165      USD  2000    5
# 3    2000-01-06  119.00  121.40  116.50  116.85    5094      USD  2000    6
# 4    2000-01-07  117.25  117.75  113.80  114.15    6855      USD  2000    7
# ...         ...     ...     ...     ...     ...     ...      ...   ...  ...
# 5741 2022-08-29  240.55  240.55  240.55  240.50       1      USD  2022  241
# 5742 2022-08-30  238.75  241.75  238.75  239.15      14      USD  2022  242
# 5743 2022-08-31  240.75  240.75  239.65  239.10      12      USD  2022  243
# 5744 2022-09-01  238.55  238.55  236.60  236.35       6      USD  2022  244
# 5745 2022-09-02  232.50  234.05  228.28  228.42       0      USD  2022  245
#
#       month
# 0         1
# 1         1
# 2         1
# ...

# %%
df['Open_Smothed'] = df['Open'].rolling(window=3, center=False).mean()

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close  Volume Currency  year  day  \
# 0 2000-01-03  122.25  124.00  116.10  116.50    6640      USD  2000    3
# 1 2000-01-04  116.25  120.50  115.75  116.25    5492      USD  2000    4
# 2 2000-01-05  115.00  121.00  115.00  118.60    6165      USD  2000    5
# 3 2000-01-06  119.00  121.40  116.50  116.85    5094      USD  2000    6
# 4 2000-01-07  117.25  117.75  113.80  114.15    6855      USD  2000    7
#
#    month  Open_Smothed
# 0      1           NaN
# 1      1           NaN
# 2      1    117.833333
# 3      1    116.750000
# 4      1    117.083333

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Currency        0
# year            0
# day             0
# month           0
# Open_Smothed    2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Currency        0
# year            0
# day             0
# month           0
# Open_Smothed    0
# dtype: int64

# %%
df
# Out:
#            Date    Open    High     Low   Close  Volume Currency  year  day  \
# 2    2000-01-05  115.00  121.00  115.00  118.60    6165      USD  2000    5
# 3    2000-01-06  119.00  121.40  116.50  116.85    5094      USD  2000    6
# 4    2000-01-07  117.25  117.75  113.80  114.15    6855      USD  2000    7
# 5    2000-01-10  123.50  126.00  116.70  117.55    7499      USD  2000   10
# 6    2000-01-11  115.50  118.25  115.50  117.80    3976      USD  2000   11
# ...         ...     ...     ...     ...     ...     ...      ...   ...  ...
# 5741 2022-08-29  240.55  240.55  240.55  240.50       1      USD  2022  241
# 5742 2022-08-30  238.75  241.75  238.75  239.15      14      USD  2022  242
# 5743 2022-08-31  240.75  240.75  239.65  239.10      12      USD  2022  243
# 5744 2022-09-01  238.55  238.55  236.60  236.35       6      USD  2022  244
# 5745 2022-09-02  232.50  234.05  228.28  228.42       0      USD  2022  245
#
#       month  Open_Smothed
# 2         1    117.833333
# ...

# %%
df2000 = df[df['year'] == 2000]
df2001 = df[df['year'] == 2001]
df2002 = df[df['year'] == 2002]
df2003 = df[df['year'] == 2003]
df2004 = df[df['year'] == 2004]
df2005 = df[df['year'] == 2005]
df2006 = df[df['year'] == 2006]
df2007 = df[df['year'] == 2007]
df2008 = df[df['year'] == 2008]
df2009 = df[df['year'] == 2009]
df2010 = df[df['year'] == 2010]
df2011 = df[df['year'] == 2011]
df2012 = df[df['year'] == 2012]
df2013 = df[df['year'] == 2013]
df2014 = df[df['year'] == 2014]
df2015 = df[df['year'] == 2015]
df2016 = df[df['year'] == 2016]
df2017 = df[df['year'] == 2017]
df2018 = df[df['year'] == 2018]
df2019 = df[df['year'] == 2019]
df2020 = df[df['year'] == 2020]

# %%
#plot each series
plt.figure(figsize=(14,8))
plt.plot(df2000["day"], df2000['Open_Smothed'], linewidth=1.5, label ="2000")
plt.fill_between(df2000["day"],df2000['Open_Smothed'], step="pre", alpha=0.2) 
plt.plot(df2001["day"], df2001['Open_Smothed'], linewidth=1.5, label ="2001")
plt.fill_between(df2001["day"], df2001['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2002["day"], df2002['Open_Smothed'], linewidth=1.5, label ="2002")
plt.fill_between(df2002["day"], df2002['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2003["day"], df2003['Open_Smothed'], linewidth=1.5, label ="2003")
plt.fill_between(df2003["day"], df2003['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2004["day"], df2004['Open_Smothed'], linewidth=1.5, label ="2004")
plt.fill_between(df2004["day"], df2004['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2005["day"], df2005['Open_Smothed'], linewidth=1.5, label ="2005")
plt.fill_between(df2005["day"], df2005['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2006["day"], df2006['Open_Smothed'], linewidth=1.5, label ="2006")
plt.fill_between(df2006["day"], df2006['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2007["day"], df2007['Open_Smothed'], linewidth=1.5, label ="2007")
plt.fill_between(df2007["day"], df2007['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2008["day"], df2008['Open_Smothed'], linewidth=1.5, label ="2008")
plt.fill_between(df2008["day"], df2008['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2009["day"], df2009['Open_Smothed'], linewidth=1.5, label ="2009")
plt.fill_between(df2009["day"], df2009['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2010["day"], df2010['Open_Smothed'], linewidth=1.5, label ="2010")
plt.fill_between(df2010["day"], df2010['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2011["day"], df2011['Open_Smothed'], linewidth=1.5, label ="2011")
plt.fill_between(df2011["day"], df2011['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2012["day"], df2012['Open_Smothed'], linewidth=1.5, label ="2012")
plt.fill_between(df2012["day"], df2012['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2013["day"], df2013['Open_Smothed'], linewidth=1.5, label ="2013")
plt.fill_between(df2013["day"], df2013['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2014["day"], df2014['Open_Smothed'], linewidth=1.5, label ="2014")
plt.fill_between(df2014["day"], df2014['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2015["day"], df2015['Open_Smothed'], linewidth=1.5, label ="2015")
plt.fill_between(df2015["day"], df2015['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2016["day"], df2016['Open_Smothed'], linewidth=1.5, label ="2016")
plt.fill_between(df2016["day"], df2016['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2017["day"], df2017['Open_Smothed'], linewidth=1.5, label ="2017")
plt.fill_between(df2017["day"], df2017['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2018["day"], df2018['Open_Smothed'], linewidth=1.5, label ="2018")
plt.fill_between(df2018["day"], df2018['Open_Smothed'], step="pre", alpha= 0.2)
plt.plot(df2019["day"], df2019['Open_Smothed'], linewidth=1.5, label ="2019")
plt.fill_between(df2019["day"], df2019['Open_Smothed'], step="pre", alpha=0.2)
plt.plot(df2020["day"], df2020['Open_Smothed'], linewidth=1.5,label ="2020")
plt.fill_between(df2020["day"], df2020['Open_Smothed'], step="pre", alpha=0.2)

#display plot


plt.ylabel('Open Price ¢/lb',fontsize=14)
plt.xlabel('Days',fontsize=14)
plt.title('Coffee Prices 2000-2020',fontsize=14, pad=20)
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.show()

# %%
df2000 = df2000.groupby('month')['Open'].mean()
df2000 = df2000.reset_index()
df2001 = df2001.groupby('month')['Open'].mean()
df2001 = df2001.reset_index()
df2002 = df2002.groupby('month')['Open'].mean()
df2002 = df2002.reset_index()
df2003 = df2003.groupby('month')['Open'].mean()
df2003 = df2003.reset_index()
df2004 = df2004.groupby('month')['Open'].mean()
df2004 = df2004.reset_index()
df2005 = df2005.groupby('month')['Open'].mean()
df2005 = df2005.reset_index()
df2006 = df2006.groupby('month')['Open'].mean()
df2006 = df2006.reset_index()
df2007 = df2007.groupby('month')['Open'].mean()
df2007 = df2007.reset_index()
df2008 = df2008.groupby('month')['Open'].mean()
df2008 = df2008.reset_index()
df2009 = df2009.groupby('month')['Open'].mean()
df2009 = df2009.reset_index()
df2010 = df2010.groupby('month')['Open'].mean()
df2010 = df2010.reset_index()
df2011 = df2011.groupby('month')['Open'].mean()
df2011 = df2011.reset_index()
df2012 = df2012.groupby('month')['Open'].mean()
df2012 = df2012.reset_index()
df2013 = df2013.groupby('month')['Open'].mean()
df2013 = df2013.reset_index()
df2014 = df2014.groupby('month')['Open'].mean()
df2014 = df2014.reset_index()
df2015 = df2015.groupby('month')['Open'].mean()
df2015 = df2015.reset_index()
df2016 = df2016.groupby('month')['Open'].mean()
df2016 = df2016.reset_index()
df2017 = df2017.groupby('month')['Open'].mean()
df2017 = df2017.reset_index()
df2018 = df2018.groupby('month')['Open'].mean()
df2018 = df2018.reset_index()
df2019 = df2019.groupby('month')['Open'].mean()
df2019 = df2019.reset_index()
df2020 = df2020.groupby('month')['Open'].mean()
df2020 = df2020.reset_index()

# %%
#plot each series
plt.figure(figsize=(8,6))
ax = plt.axes()
ax.set_facecolor("Ivory")

plt.stem(df2000['month'],df2000['Open'], label ="2000",markerfmt = 'DC0', linefmt = ':', basefmt=" ")
plt.stem(df2001['month'],df2001['Open'], label ="2001",markerfmt = 'DC0', linefmt = ':', basefmt=" ")
plt.stem(df2002['month'],df2002['Open'], label ="2002",markerfmt = 'DC0', linefmt = ':', basefmt=" ")
plt.stem(df2003['month'],df2003['Open'], label ="2003",markerfmt = 'DC0', linefmt = ':', basefmt=" ")
plt.stem(df2004['month'],df2004['Open'], label ="2004",markerfmt = 'DC0', linefmt = ':', basefmt=" ")
plt.stem(df2005['month'],df2005['Open'], label = "2005",markerfmt ='DC0', linefmt = ':', basefmt=" ")
plt.stem(df2006['month'],df2006['Open'],markerfmt = 'Dg', label = "2006", linefmt = ':', basefmt=" ")
plt.stem(df2007['month'],df2007['Open'],markerfmt = 'Dg', label = "2007", linefmt = ':', basefmt=" ")
plt.stem(df2008['month'],df2008['Open'],markerfmt = 'Dg', label ="2008", linefmt = ':', basefmt=" ")
plt.stem(df2009['month'],df2009['Open'],markerfmt = 'Dg', label ="2009", linefmt = ':', basefmt=" ")
plt.stem(df2010['month'],df2010['Open'],markerfmt = 'Dg', label ="2010", linefmt = ':', basefmt=" ")
plt.stem(df2011['month'],df2011['Open'],markerfmt = 'DC1', label ="2011", linefmt = ':', basefmt=" ")
plt.stem(df2012['month'],df2012['Open'],markerfmt = 'DC1', label = "2012", linefmt = ':', basefmt=" ")
plt.stem(df2013['month'],df2013['Open'],markerfmt = 'DC1', label = "2013", linefmt = ':', basefmt=" ")
plt.stem(df2014['month'],df2014['Open'],markerfmt = 'DC1', label = "2014", linefmt = ':', basefmt=" ")
plt.stem(df2015['month'],df2015['Open'],markerfmt = 'DC1', label = "2015", linefmt = ':', basefmt=" ")
plt.stem(df2016['month'],df2016['Open'],markerfmt = 'Dy', label = "2016", linefmt = ':', basefmt=" ")
plt.stem(df2017['month'],df2017['Open'],markerfmt = 'Dy', label = "2017", linefmt = ':', basefmt=" ")
plt.stem(df2018['month'],df2018['Open'],markerfmt = 'Dy', label = "2018", linefmt = ':', basefmt=" ")
plt.stem(df2019['month'],df2019['Open'],markerfmt = 'Dy', label = "2019", linefmt = ':',basefmt=" ")
plt.stem(df2020['month'],df2020['Open'],markerfmt = 'Dy', label = "2020", linefmt = ':', basefmt=" ")



plt.axhline(y = 125, color = 'red', linestyle = ':', label = "Midpoint")
plt.ylabel('Average Open Price ¢/lb', fontsize=14)
plt.xlabel('Months',fontsize=14)
plt.title('Coffee Prices 2000-2020',fontsize=14,pad=20)
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left',facecolor="Ivory")
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.show()
